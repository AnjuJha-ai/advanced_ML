# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
Wine=datasets.load_wine()

# %%
x=Wine.data
y=Wine.target
col1=Wine.feature_names
col2=Wine.target_names

# %%
df=pd.DataFrame(x,columns=col1)

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df['target'] = y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['target'] = y
#
# NameError: name 'y' is not defined

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
df.corr()
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
# target                       -0.328222    0.437776 -0.049643
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# filter method using information gain of feature for feature selection
from sklearn.feature_selection import mutual_info_classif

# %%
importances=mutual_info_classif(x,y)
feat_importances=pd.Series(importances,df.columns[0:len(df.columns)-1])
feat_importances.plot(kind='barh',color='Red')
plt.show()

# %%
# chisquare test is used for categorical features in a dataset.
#calculate chi square between each feature and the target and select the desired number of features with the best chi square score.
# in order to correctly apply chi squared to test the relation between various feature

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
#convert categorical by integer
#x=x.astype(int)
#three features with highest chi-squared statistics are selected
chi2_features=SelectKBest(chi2,k=5)
x_bestfeature=chi2_features.fit_transform(x,y)

#Reduced features

print('Original features:',x.shape[1])
print('reduced feature:',x_bestfeature.shape[1])
# Out:
# Original features: 13
# reduced feature: 5

# %% [markdown]
# # flow work
#
# 1 import dataset from sklearn or load from file by importing.
# 2 check data describe and info
# 3 checking null value
# 4 if null value then replace or drop and give conclusion why
# 5 check for duplicate value
# 6 if yes duplicate value the replace or perform task and give conclution
# 7 identify outlier using boxplot
# 8 remove outlier using zscore,IQR,and then boxplot
# 9 feature scaling using normalizer, standardizer,min max and robust
# 10 feature selection filter method---correlation, chisquare,information gain, fisher score (any two)
# Note:Before feature scaling perform EDA(Visuals) for every columns like bar,pie,histogram and also give conclusion from graph.

# %%
#!pip install skfeature-chappers

# %%
from skfeature.function.similarity_based import fisher_score
# gives ranking on the basis of feature importance
rank=fisher_score.fisher_score(x,y)

#plotting rank

feat_imp=pd.Series(rank,df.columns[0:len(df.columns)-1])
feat_imp.plot(kind='barh', color='blue')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
#elbow method
error_rate=[]
for i in range(1,10):
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train,y_train)
    prediction=model.predict(x_test)
    error_rate.append(np.mean(prediction!=y_test))

# %%
plt.figure(figsize=(8,8))
plt.plot(range(1,10),error_rate,color='blue',linestyle='dotted',marker='x')
plt.title('Error rate vs k')
plt.xlabel('k')
plt.ylabel('error rate')
# Out:
# Text(0, 0.5, 'error rate')

# %%
# from sklearn.neighbors import KNeighborsRegressor
#elbow method
error_rate=[]
for i in range(1,13):
    model=KNeighborsRegressor(n_neighbors=i)
    model.fit(x_train,y_train)
    prediction=model.predict(x_test)
    error_rate.append(np.mean(prediction!=y_test))

# %%
# plt.figure(figsize=(10,10))
plt.plot(range(1,13),error_rate,color='blue',linestyle='dotted',marker='x')
plt.title('Error rate vs k')
plt.xlabel('k')
plt.ylabel('error rate')

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
result_df=pd.DataFrame(columns=['Model','Accuracy Score'])
models=[('KNN',KNeighborsClassifier(n_neighbors=9))]

for name, model in models:
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    performance_score=accuracy_score(y_test,y_pred)
    new_row={'Model':name,'Accuracy Score':performance_score}

# %%
performance_score
# Out:
# 0.6666666666666666

# %%
a=confusion_matrix(y_test,y_pred)

# %%
print (a)
# Out:
# [[10  0  0]
#  [ 2  8  4]
#  [ 4  2  6]]

# %%
sns.heatmap(a,annot=True)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
