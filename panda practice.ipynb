# %%
import pandas as pd

# %%
data=pd.read_csv('titanic_train.csv')

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.shape
# Out:
# (891, 12)

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a)
print(a)
# Out:
# [1, 7, 2]

# %%
myvar=pd.Series(a,index=['X','Y','Z'])
myvar
# Out:
# X    1
# Y    7
# Z    2
# dtype: int64

# %%
df={
    'calories':[500,6000,790],
    'duration':[40,75,65]
}
print(df)
# Out:
# {'calories': [500, 6000, 790], 'duration': [40, 75, 65]}

# %%
import pandas as pd
df1=pd.DataFrame(df)
df1
# Out:
#    calories  duration
# 0       500        40
# 1      6000        75
# 2       790        65

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1=data.dropna()

# %%
data1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
x=data['PassengerId']
y=data['Age']
plt.bar(x,y,label='Age',color='Blue')
plt.xlabel('Passenger ID')
plt.ylabel('Passenger Age')
plt.title('Passenger info')
plt.legend()
plt.show()

# %%
import numpy as np
outliers=[]
def detect_outliers_zscore(data):
    thres=3
    mean=np.mean(data)
    std=np.std(data)
    print(mean,std)
    
    for i in data:
        z_score=(i-mean)/std
        if(np.abs(z_score)>thres):
            outliers.append(i)
    return outliers
sample_outliers=detect_outliers_zscore(data['Age'])
print("outliers from zscore:",sample_outliers)
# Out:
# 29.69911764705882 14.516321150817317
# outliers from zscore: [80.0, 74.0]

# %%
import numpy as np
outliers=[]
def detect_outliers_zscore(data):
    thres=3
    mean=np.mean(data)
    std=np.std(data)
    print(mean,std)
    
    for i in data:
        z_score=(i-mean)/std
        if(np.abs(z_score)>thres):
            outliers.append(i)
    return outliers
sample_outliers=detect_outliers_zscore(data['Fare'])
print("outliers from zscore:",sample_outliers)
# Out:
# 32.204207968574636 49.66553444477411
# outliers from zscore: [263.0, 263.0, 247.5208, 512.3292, 247.5208, 262.375, 263.0, 211.5, 227.525, 263.0, 221.7792, 227.525, 512.3292, 211.3375, 227.525, 227.525, 211.3375, 512.3292, 262.375, 211.3375]

# %% [markdown]
# # IQR
#  defines difference between third and first quantile

# %%
outliers=[]
def detect_outliers_iqr(data):
    data=sorted(data)
    q1=np.percentile(data,25)
    q3=np.percentile(data,75)
    print(q1,q3)
    IQR=q3-q1
    lwr_bound=q1-(1.5*IQR)
    upr_bound=q3+(1.5*IQR)
    print(lwr_bound,upr_bound)
    for i in data:
        if(i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers
sample_outliers=detect_outliers_iqr(data['Fare'])
print("outliers from IQR:",sample_outliers)
print(sample_outliers)
# Out:
# 7.9104 31.0
# -26.724 65.6344
# outliers from IQR: [66.6, 66.6, 69.3, 69.3, 69.55, 69.55, 69.55, 69.55, 69.55, 69.55, 69.55, 71.0, 71.0, 71.2833, 73.5, 73.5, 73.5, 73.5, 73.5, 75.25, 76.2917, 76.7292, 76.7292, 76.7292, 77.2875, 77.2875, 77.9583, 77.9583, 77.9583, 78.2667, 78.2667, 78.85, 78.85, 79.2, 79.2, 79.2, 79.2, 79.65, 79.65, 79.65, 80.0, 80.0, 81.8583, 82.1708, 82.1708, 83.1583, 83.1583, 83.1583, 83.475, 83.475, 86.5, 86.5, 86.5, 89.1042, 89.1042, 90.0, 90.0, 90.0, 90.0, 91.0792, 91.0792, 93.5, 93.5, 106.425, 106.425, 108.9, 108.9, 110.8833, 110.8833, 110.8833, 110.8833, 113.275, 113.275, 113.275, 120.0, 120.0, 120.0, 120.0, 133.65, 133.65, 134.5, 134.5, 135.6333, 135.6333, 135.6333, 146.5208, 146.5208, 151.55, 151.55, 151.55, 151.55, 153.4625, 153.4625, 153.4625, 164.8667, 164.8667, 211.3375, 211.3375, 211.3375, 211.5, 221.7792, 227.525, 227.525, 227.525, 227.525, 247.5208, 247.5208, 262.375, 262.375, 263.0, 263.0, 263.0, 263.0, 512.3292, 512.3292, 512.3292]
# ...

# %%
#trimming

for i in sample_outliers:
    a=np.delete(data,np.where(data==i))
print(a)
#print(len(data),len(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 #trimming
#       3 for i in sample_outliers:
# ----> 4     a=np.delete(data,np.where(data==i))
#       5 print(a)
#
# File <__array_function__ internals>:200, in delete(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5241, in delete(arr, obj, axis)
#    5238     new = arr[tuple(slobj)]
#    5240 if wrap:
# -> 5241     return wrap(new)
#    5242 else:
#    5243     return new
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2107, in NDFrame.__array_wrap__(self, result, context)
#    2105     return res
#    2106 d = self._construct_axes_dict(self._AXIS_ORDERS, copy=False)
# -> 2107 return self._constructor(res, **d).__finalize__(self, method="__array_wrap__")
#
# ...

# %%
median=np.median(data["Fare"])#replace by median

for i in sample_outliers:
    c=np.where(data["Fare"]==i,14,data["Fare"])
    print("sample:",data["Fare"])
    print("new array:",c)
    print(c.dtype)
# Out:
# sample: 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64
# new array: [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55     8.05    31.275    7.8542  16.
#   29.125   13.      18.       7.225   26.      13.       8.0292  35.5
#   21.075   31.3875   7.225  263.       7.8792   7.8958  27.7208 146.5208
#    7.75    10.5     82.1708  52.       7.2292   8.05    18.      11.2417
#    9.475   21.       7.8958  41.5792   7.8792   8.05    15.5      7.75
#   21.6792  17.8     39.6875   7.8     76.7292  26.      61.9792  35.5
#   10.5      7.2292  27.75    46.9      7.2292  80.      83.475   27.9
#   27.7208  15.2458  10.5      8.1583   7.925    8.6625  10.5     46.9
#   73.5     14.4542  56.4958   7.65     7.8958   8.05    29.      12.475
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(c,vert=False)
plt.title("boxplot of the sample after treating the outliers")
plt.xlabel("sample")
# Out:
# Text(0.5, 0, 'sample')

# %%
median=np.median(data["Fare"])#replace by median

for i in data["Fare"]:
    for j in sample_outliers:
        c=np.where(i==j,median,data["Fare"])
print("sample:",data["Fare"])
print("new array:",c)
print(c.dtype)
# Out:
# sample: 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64
# new array: [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55     8.05    31.275    7.8542  16.
#   29.125   13.      18.       7.225   26.      13.       8.0292  35.5
#   21.075   31.3875   7.225  263.       7.8792   7.8958  27.7208 146.5208
#    7.75    10.5     82.1708  52.       7.2292   8.05    18.      11.2417
#    9.475   21.       7.8958  41.5792   7.8792   8.05    15.5      7.75
#   21.6792  17.8     39.6875   7.8     76.7292  26.      61.9792  35.5
#   10.5      7.2292  27.75    46.9      7.2292  80.      83.475   27.9
#   27.7208  15.2458  10.5      8.1583   7.925    8.6625  10.5     46.9
#   73.5     14.4542  56.4958   7.65     7.8958   8.05    29.      12.475
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(c,vert=False)
plt.title("boxplot of the sample after treating the outliers")
plt.xlabel("sample")
# Out:
# Text(0.5, 0, 'sample')
