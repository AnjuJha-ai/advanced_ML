# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import datasets

# %%
bc=datasets.load_breast_cancer()
x=bc.data
y=bc.target

# %%
col=bc.feature_names

# %%
df=pd.DataFrame(x,columns=col)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
plt.figure(figsize=(15,6))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    569
# dtype: int64

# %%
df.clip(df.quantile(0.25),df.quantile(0.75),axis=1,inplace=True)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler,Normalizer,MinMaxScaler,RobustScaler

# %%
S=StandardScaler()

# %%
X=S.fit_transform(df)

# %%
X=pd.DataFrame(X,columns=col)

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     1.320229     -1.222910        1.338518   1.374659         1.233979
# 1     1.320229     -0.521913        1.338518   1.374659        -1.215728
# 2     1.320229      1.002755        1.338518   1.374659         1.233979
# 3    -1.150539      0.621588       -0.925929  -1.106312         1.233979
# 4     1.320229     -1.222910        1.338518   1.374659         0.586936
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          1.267724        1.359742             1.385364       1.217176
# 1         -0.654632        0.307065             1.212800       0.168305
# 2          1.267724        1.359742             1.385364       1.217176
# 3          1.267724        1.359742             1.385364       1.217176
# 4          1.267724        1.359742             1.385364       0.146604
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df['target']=y

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          15.78         16.17          104.10      782.7          0.10530
# 1          15.78         17.77          104.10      782.7          0.08637
# 2          15.78         21.25          104.10      782.7          0.10530
# 3          11.70         20.38           77.58      420.3          0.10530
# 4          15.78         16.17          104.10      782.7          0.10030
# ..           ...           ...             ...        ...              ...
# 564        15.78         21.80          104.10      782.7          0.10530
# 565        15.78         21.80          104.10      782.7          0.09780
# 566        15.78         21.80          104.10      782.7          0.08637
# 567        15.78         21.80          104.10      782.7          0.10530
# 568        11.70         21.80           75.17      420.3          0.08637
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import SelectKBest,mutual_info_classif

# %%
i=mutual_info_classif(X,y)
feat=pd.Series(i,df.columns[0:len(df.columns)-1])
feat.plot(kind='barh',color='red')
plt.show()

# %%
a=SelectKBest(mutual_info_classif,k=10)
R=a.fit_transform(X,y)

# %%
R.shape
# Out:
# (569, 10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
R_train, R_test, y_train, y_test = train_test_split(R, y, test_size=0.33, random_state=42)

# %%
k=KNeighborsClassifier()

# %%
k.fit(R_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=k.predict(R_test)

# %%
print(k.predict([[2,5,9,3.8,5.7,124,236,21,57,900]]))
# Out:
# [0]

# %%
from sklearn.metrics import confusion_matrix,classification_report,f1_score,accuracy_score

# %%
b=confusion_matrix(y_pred,y_test)
sns.heatmap(b,annot=True)
plt.xlabel('prediction')
plt.ylabel('actual')
plt.show()

# %%
c=accuracy_score(y_test,y_pred)
print(c)
# Out:
# 0.9414893617021277

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        67
#            1       0.96      0.95      0.95       121
#
#     accuracy                           0.94       188
#    macro avg       0.94      0.94      0.94       188
# weighted avg       0.94      0.94      0.94       188

# %%
from sklearn.svm import SVC

# %%
D=SVC()

# %%
D.fit(R_train,y_train)
# Out:
# SVC()

# %%
y_p=D.predict(R_test)

# %%
print(accuracy_score(y_p,y_test))
# Out:
# 0.9468085106382979

# %%
from sklearn.model_selection import GridSearchCV

# %%
p={'C':[0.01,0.1,1,0.001],'kernel':['linear','poly','rbf','sigmoid'],'gamma':['scale','auto'],'degree':[1,2,3,4,5]}

# %%
g=GridSearchCV(D,p,cv=3)

# %%
g.fit(R_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1, 0.001], 'degree': [1, 2, 3, 4, 5],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
y_pr=g.predict(R_test)

# %%
g.best_params_
# Out:
# {'C': 0.1, 'degree': 1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
A=accuracy_score(y_pr,y_test)
print(A)
# Out:
# 0.9627659574468085

# %%
D=SVC(C=100,gamma='auto',kernel='poly',degree=3)

# %%
D.fit(R_train,y_train)
# Out:
# SVC(C=100, gamma='auto', kernel='poly')

# %%
y1=D.predict(R_test)

# %%
q=accuracy_score(y1,y_test)
print(q)
# Out:
# 0.9680851063829787

# %%
D=SVC(C=0.01,gamma='scale',kernel='rbf',degree=3)

# %%
D.fit(R_train,y_train)
# Out:
# SVC(C=0.01)

# %%
y2=D.predict(R_test)

# %%
w=accuracy_score(y2,y_test)
print(w)
# Out:
# 0.9414893617021277

# %%
name=['poly','linear','rbf']
accuracy=[q,A,w]
plt.bar(name,accuracy)
plt.xlabel('function')
plt.ylabel('accuracy')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
