# %%
from math import sqrt
import math as m
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
Wine=datasets.load_wine()

# %%
x=Wine.data
y=Wine.target
col1=Wine.feature_names
col2=Wine.target_names

# %%
df=pd.DataFrame(x,columns=col1)

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
def euclidean_distance(row1,row2):
    distance=0.0
    print(len(row1))
    for i in range(len(row1)-1):
        distance+=(row1[i]-row2[i])**2
    return sqrt(distance)

# %%
dataset=[[1,2,3],[1.2,2.4,3.2],[2.6,2,3],[1,3,2],[5,4,3],[3,4,5],[6,5,4],[7,4,2]]
row0=dataset[0]
print(row0)
for row in dataset:
    print(row)
    distance=euclidean_distance(row0,row)
    print(distance)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# 3
# 0.0
# [1.2, 2.4, 3.2]
# 3
# 0.4472135954999578
# [2.6, 2, 3]
# 3
# 1.6
# [1, 3, 2]
# 3
# 1.0
# [5, 4, 3]
# 3
# 4.47213595499958
# [3, 4, 5]
# 3
# 2.8284271247461903
# [6, 5, 4]
# 3
# 5.830951894845301
# [7, 4, 2]
# 3
# 6.324555320336759

# %%
def get_neighbour(train,test_row,num_neighbour):
    distances=list()
    for train_row in train:
        dist=euclidean_distance(test_row,train_row)
        distances.append((train_row,dist))
        distances.sort(key=lambda tup: tup[1])
    neighbours=list()
    for i in range(num_neighbour):
        neighbours.append(distances[i][0])
    return neighbours
#get_neighbour(4,4,2)

# %%
dataset=[[1,2,3],[1.2,2.4,3.2],[2.6,2,3],[1,3,2],[5,4,3],[3,4,5],[6,5,4],[7,4,2]]
row0=dataset[0]
print(row0)
neighbours=get_neighbours(dataset,dataset[0],3)
for neighbour in neighbours:
    print(neighbour)
# Out:
# [1, 2, 3]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 row0=dataset[0]
#       3 print(row0)
# ----> 4 neighbours=get_neighbours(dataset,dataset[0],3)
#       5 for neighbour in neighbours:
#       6     print(neighbour)
#
# NameError: name 'get_neighbours' is not defined

# %%
def Haming_distance(row1,row2):
    distance=0.0
    print(len(row1))
    for i in range(len(row1)-1):
        ham_distance+=abs((row1[i]-row2[i]))
    return (ham_distance)

# %%
dataset=[[1,2,3],[1.2,2.4,3.2],[2.6,2,3],[1,3,2],[5,4,3],[3,4,5],[6,5,4],[7,4,2]]
row0=dataset[0]
print(row0)
for row in dataset:
    print(row)
    ham_distance=Haming_distance(row0,row)
    print(ham_distance)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# 3
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[11], line 6
#       4 for row in dataset:
#       5     print(row)
# ----> 6     ham_distance=Haming_distance(row0,row)
#       7     print(ham_distance)
#
# Cell In[10], line 5, in Haming_distance(row1, row2)
#       3 print(len(row1))
#       4 for i in range(len(row1)-1):
# ----> 5     ham_distance+=abs((row1[i]-row2[i]))
#       6 return (ham_distance)
#
# UnboundLocalError: cannot access local variable 'ham_distance' where it is not associated with a value

# %%
def Manhattan_distance(row1,row2):
    distance=0.0
    print(len(row1))
    for i in range(len(row1)-1):
        man_distance+=m.modf(row1[i]+row2[i])
    return (man_distance)

# %%
dataset=[[1,2,3],[1.2,2.4,3.2],[2.6,2,3],[1,3,2],[5,4,3],[3,4,5],[6,5,4],[7,4,2]]
row1=dataset[0]
print(row1)
for row in dataset:
    print(row)
    man_distance=Manhattan_distance(row1,row)
    print(ham_distance)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# 3
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[13], line 6
#       4 for row in dataset:
#       5     print(row)
# ----> 6     man_distance=Manhattan_distance(row1,row)
#       7     print(ham_distance)
#
# Cell In[12], line 5, in Manhattan_distance(row1, row2)
#       3 print(len(row1))
#       4 for i in range(len(row1)-1):
# ----> 5     man_distance+=m.modf(row1[i]+row2[i])
#       6 return (man_distance)
#
# UnboundLocalError: cannot access local variable 'man_distance' where it is not associated with a value
