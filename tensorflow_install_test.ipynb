# %%
# !pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 48.7/48.7 kB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/385.0 MB ? eta -:--:--
#    ---------------------------------------- 0.2/385.0 MB 14.3 MB/s eta 0:00:27
#    ---------------------------------------- 0.9/385.0 MB 11.8 MB/s eta 0:00:33
#    ---------------------------------------- 2.3/385.0 MB 20.9 MB/s eta 0:00:19
#    ---------------------------------------- 3.2/385.0 MB 20.6 MB/s eta 0:00:19
#    ---------------------------------------- 4.5/385.0 MB 21.9 MB/s eta 0:00:18
#     --------------------------------------- 5.9/385.0 MB 25.4 MB/s eta 0:00:15
#     --------------------------------------- 6.8/385.0 MB 24.2 MB/s eta 0:00:16
#     --------------------------------------- 7.6/385.0 MB 24.3 MB/s eta 0:00:16
#     --------------------------------------- 8.4/385.0 MB 22.3 MB/s eta 0:00:17
# ...

# %%
import tensorflow as tf
a = tf.constant(2)
b = tf.constant(3)
c = tf.add(a, b)
result = c.numpy()  # Convert to a NumPy array
print(result)  # You should see '5' printed to the console.
# Out:
# 5
